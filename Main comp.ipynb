# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import cross_val_predict , GridSearchCV, RepeatedStratifiedKFold , cross_val_score
from sklearn import neighbors, datasets
from sklearn.decomposition import PCA

kValues = list(range(1,25))
wine = datasets.load_wine()

y = wine.target
for ii in range(2,13):
    X = wine.data[:, :ii]
    pca = PCA(n_components=2)
    X = pca.fit_transform(X)


    colors = "bgy"
    target_names=wine.target_names
    cv_scores = []

    for k in kValues:
        clf = neighbors.KNeighborsClassifier(n_neighbors = k)
        clf.fit(X, y)
        scores = cross_val_score(clf, X, y, cv=10, scoring='accuracy')
        cv_scores.append(scores.mean())



    # changing to misclassification error
    MSE = [1 - x for x in cv_scores]

    # determining the best k
    print("Было "+str(ii)+"  признаков")
    optimal_k = kValues[MSE.index(min(MSE))]
    print("The optimal number of neighbors  is %d" 
          % ( optimal_k))
    print("MSE", min(MSE))


    kNN = neighbors.KNeighborsClassifier(n_neighbors = optimal_k)
    kNN.fit(X, y)



    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1))


    plt.subplots( figsize=(10, 8))
    clf=kNN

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.5)
    for color, i ,  target_name in zip(colors,[0, 1, 2], target_names):
        plt.scatter(X[y==i, 0], X[y==i, 1], alpha=.8, color=color,
                    label=target_name)
    plt.legend(loc='best', shadow=False, scatterpoints=1)




    plt.show()
# Out:
# Было 2  признаков
# The optimal number of neighbors  is 15
# MSE 0.18325378396972825
# Было 3  признаков
# The optimal number of neighbors  is 15
# MSE 0.1779906260749915
# Было 4  признаков
# The optimal number of neighbors  is 9
# MSE 0.26932404540763677
# Было 5  признаков
# The optimal number of neighbors  is 5
# MSE 0.31844685242518056
# Было 6  признаков
# The optimal number of neighbors  is 5
# MSE 0.31844685242518056
# Было 7  признаков
# The optimal number of neighbors  is 7
# MSE 0.319031647746818
# Было 8  признаков
# The optimal number of neighbors  is 7
# MSE 0.319031647746818
# Было 9  признаков
# The optimal number of neighbors  is 6
# MSE 0.3023649810801513
# Было 10  признаков
# The optimal number of neighbors  is 7
# MSE 0.3137684898520813
# Было 11  признаков
# The optimal number of neighbors  is 7
# MSE 0.3137684898520813
# Было 12  признаков
# The optimal number of neighbors  is 7
# MSE 0.31376848985208117
